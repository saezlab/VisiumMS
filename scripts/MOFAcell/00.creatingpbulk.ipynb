# %%
#!/usr/bin/env python
# coding: utf-8
import sys
import scanpy as sc
import anndata
import pandas as pd
import numpy as np
import os
import gc
import decoupler as dc
import regex as re
os.chdir("/Users/ricardoramirez/Dropbox/PostDoc/Research/MS")

# %%
sc_dat = sc.read_h5ad(filename = "./data/adata_raw_cellbender.h5ad")

# %%
list(sc_dat.obs.columns)
# Out:
# ['n_genes',
#  'n_genes_by_counts',
#  'total_counts',
#  'total_counts_mt',
#  'pct_counts_mt',
#  'doublet_score',
#  'predicted_doublet',
#  'diss_score',
#  'patient_id',
#  'sample_id',
#  'Condition',
#  'lesion_type',
#  'Age',
#  'Sex',
#  'RIN',
#  'Batch',
#  'visium',
#  'snRNA-seq',
#  'batch',
#  'leiden',
#  'cell_types']

# %%
meta_data_cols = ["patient_id", "sample_id", "lesion_type", "Age", "Sex", "RIN", "Batch"]

# %%
available_cells = sc_dat.obs[["cell_types"]].drop_duplicates()
available_cells
# Out:
#                          cell_types
# CO37_ACCTACCGTATGCTAC-1     Neurons
# CO37_TCGCAGGGTCCAACGC-1         OPC
# CO37_CATGGTAAGCTACTAC-1      Oligos
# CO37_ACCATTTTCAGACTGT-1      Astros
# CO37_GTTACGAGTCGGTGTC-1    Astros_c
# CO37_GCTGCAGTCTCTAGGA-1  Endothelia
# CO37_GATCACATCTCGAGTA-1   Microglia
# CO37_ACAGGGATCTCATAGG-1      Stroma
# CO37_ACCATTTAGTGCCAGA-1     T_cells
# CO41_CTTCGGTTCCCTCTCC-1     B_cells

# %%
meta_data = sc_dat.obs[meta_data_cols].drop_duplicates()

# %%
meta_data
# Out:
#                             patient_id sample_id lesion_type  Age Sex  RIN
# CO37_ACCTACCGTATGCTAC-1      CO37 P5B3      CO37        Ctrl   87   M  6.1  \
# CO40_CCTCTCCGTGTGAATA-1    PDCO40 A1B2      CO40        Ctrl   61   F  7.8
# CO41_ACCAAACTCTCTCTTC-1      CO41 A1C4      CO41        Ctrl   54   M  7.2
# CO45_TCACTATGTCTCACAA-1      CO45 A1D4      CO45        Ctrl   77   M  6.4
# CO74_GAAGGACAGAAACACT-1      CO74 A1A2      CO74        Ctrl   84   F  7.0
# CO85_CTTACCGTCACATTGG-1      CO85 A3C2      CO85        Ctrl   81   F  5.9
# MS197_TATCTTGGTTTCTTAC-1    MS197 P2D3     MS197          CA   52   F  9.0
# MS229_TTTATGCCACCCTAAA-1    MS229 P2C2     MS229          CA   53   M  7.0
# MS371N_TCTATACGTGGCACTC-1   MS371 A3D6    MS371N           A   40   M  7.6
# MS377I_AGGGCCTAGCTTAGTC-1   MS377 A2D4    MS377I          CA   50   F  6.5
# MS377N_AATTTCCCAGGAACCA-1   MS377 A2D2    MS377N          CA   50   F  8.9
# MS377T_TCATCCGTCCTAAACG-1   MS377 A2D4    MS377T          CA   50   F  6.5
# MS411_TCCACCACAGCTTCCT-1    MS411 A2A2     MS411          CA   61   M  5.9
# MS466_ACCGTTCCACTTGTCC-1    MS466 A1D6     MS466          CI   65   F  6.5
# MS497I_TACCCACCACAACGCC-1   MS497 A3C2    MS497I          CI   60   F  6.1
# MS497T_AGAACCTGTAACATCC-1   MS497 A3C2    MS497T          CI   60   F  6.1
# MS549H_TCTAACTAGCATGATA-1   MS549 P2D5    MS549H          CI   50   M  8.0
# MS549T_ATTCTTGAGACCCGCT-1   MS549 P2D5    MS549T          CI   50   M  8.0
# MS586_ACTTCCGCACATTCTT-1    MS586 A1B2     MS586           A   57   F  7.1
#
#                            Batch
# CO37_ACCTACCGTATGCTAC-1        4
# CO40_CCTCTCCGTGTGAATA-1        1
# CO41_ACCAAACTCTCTCTTC-1        4
# CO45_TCACTATGTCTCACAA-1        4
# CO74_GAAGGACAGAAACACT-1        2
# CO85_CTTACCGTCACATTGG-1        3
# MS197_TATCTTGGTTTCTTAC-1       4
# MS229_TTTATGCCACCCTAAA-1       4
# MS371N_TCTATACGTGGCACTC-1      4
# MS377I_AGGGCCTAGCTTAGTC-1      1
# MS377N_AATTTCCCAGGAACCA-1      4
# MS377T_TCATCCGTCCTAAACG-1      1
# MS411_TCCACCACAGCTTCCT-1       1
# MS466_ACCGTTCCACTTGTCC-1       1
# MS497I_TACCCACCACAACGCC-1      3
# MS497T_AGAACCTGTAACATCC-1      2
# MS549H_TCTAACTAGCATGATA-1      2
# MS549T_ATTCTTGAGACCCGCT-1      3
# MS586_ACTTCCGCACATTCTT-1       4

# %%
meta_data.to_csv("./data/meta_data.csv")

# %%
cell_type_numbers = sc_dat.obs.groupby(["sample_id", "cell_types"])["cell_types"].count()
cell_type_numbers = cell_type_numbers.to_frame().rename({"cell_types":"counts"}, axis=1).reset_index()

# %%
cell_type_numbers
# Out:
#     sample_id  cell_types  counts
# 0        CO37      Astros     746
# 1        CO37    Astros_c      16
# 2        CO37     B_cells       0
# 3        CO37  Endothelia      37
# 4        CO37   Microglia     396
# ..        ...         ...     ...
# 185     MS586     Neurons      39
# 186     MS586         OPC     188
# 187     MS586      Oligos    4599
# 188     MS586      Stroma      21
# 189     MS586     T_cells      15
#
# [190 rows x 3 columns]

# %%
sc_dat.layers['counts'] = sc_dat.X
padata = dc.get_pseudobulk(sc_dat, 
                           sample_col='sample_id', 
                           groups_col='cell_types', 
                           layer='counts', 
                           min_prop=0, 
                           min_smpls=0,
                           mode='sum')

# %%
pb_dat = pd.DataFrame(padata.X)
pb_dat.columns = padata.var.index.values
pb_dat.index = padata.obs.index.values
pb_dat.to_csv("./data/pb_data.csv")

# %%
pb_coldata = padata.obs.copy()
pb_coldata["colname"] = pb_coldata.index.values

# %%
pb_coldata = pb_coldata.merge(cell_type_numbers, on = ["cell_types","sample_id"], how = "left")

# %%
pb_coldata

# %%
pb_coldata.to_csv("./data/pb_coldata.csv")
